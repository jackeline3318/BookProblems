# %%
import pandas as pd

# %%
A = pd.read_csv(r"C:\Users\gisse\Downloads\BlueOrRed.csv")

# %%
A
# Out:
#       Voter  Age  HomeOwner  Female  Married  HouseholdSize  Income  \
# 0         1   51          1       1        1              4   171.0
# 1         2   46          1       1        1              6   420.0
# 2         3   55          1       0        1              6   132.0
# 3         4   50          1       0        1              4    18.0
# 4         5   49          1       1        1              2    66.0
# ...     ...  ...        ...     ...      ...            ...     ...
# 9995   9996   55          1       1        1              2    37.0
# 9996   9997   29          1       1        0              5   100.0
# 9997   9998   59          0       1        0              1    35.0
# 9998   9999   66          0       0        1              3     4.0
# 9999  10000   55          1       1        1              4    19.0
#
#       Education  Church Undecided
# 0            15       0       Yes
# 1            15       1        No
# 2            16       0       Yes
# ...

# %%
import pandas as pd
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
import numpy as np

A = pd.read_csv(r"C:\Users\gisse\Downloads\BlueOrRed.csv")

X = A[['Age', 'HouseholdSize', 'Income', 'Education']]
y = A['Undecided']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_val, y_train, y_val = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

def find_optimal_k(X_train, y_train, max_k=20):
    error_rates = []
    k_values = list(range(1, max_k + 1))

    for k in k_values:
        knn = KNeighborsClassifier(n_neighbors=k)
        cv_scores = cross_val_score(knn, X_train, y_train, cv=10, scoring='accuracy')
        error_rate = 1 - np.mean(cv_scores)
        error_rates.append(error_rate)

    optimal_k = k_values[np.argmin(error_rates)]
    return optimal_k

optimal_k = find_optimal_k(X_train, y_train)

final_knn_model = KNeighborsClassifier(n_neighbors=optimal_k)
final_knn_model.fit(X_train, y_train)

accuracy = final_knn_model.score(X_val, y_val)
error_rate = 1 - accuracy

print(f"Optimal k: {optimal_k}")
print(f"Validation Set Accuracy: {accuracy:.4f}")
print(f"Validation Set Error Rate: {error_rate:.4f}")
# Out:
# Optimal k: 20
# Validation Set Accuracy: 0.8040
# Validation Set Error Rate: 0.1960

# %%
import pandas as pd
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
import numpy as np

A = pd.read_csv(r"C:\Users\gisse\Downloads\BlueOrRed.csv")

X = A.drop('Undecided', axis=1)
y = A['Undecided']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_val, y_train, y_val = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

def find_optimal_k(X_train, y_train, max_k=20):
    error_rates = []
    k_values = list(range(1, max_k + 1))

    for k in k_values:
        knn = KNeighborsClassifier(n_neighbors=k)
        cv_scores = cross_val_score(knn, X_train, y_train, cv=10, scoring='accuracy')
        error_rate = 1 - np.mean(cv_scores)
        error_rates.append(error_rate)

    optimal_k = k_values[np.argmin(error_rates)]
    return optimal_k

optimal_k = find_optimal_k(X_train, y_train)

final_knn_model = KNeighborsClassifier(n_neighbors=optimal_k)
final_knn_model.fit(X_train, y_train)

accuracy = final_knn_model.score(X_val, y_val)
error_rate = 1 - accuracy

print(f"Optimal k: {optimal_k}")
print(f"Validation Set Accuracy: {accuracy:.4f}")
print(f"Validation Set Error Rate: {error_rate:.4f}")
# Out:
# Optimal k: 7
# Validation Set Accuracy: 0.9285
# Validation Set Error Rate: 0.0715

# %%
X_continuous = A[['Age', 'HouseholdSize', 'Income', 'Education']]
X_continuous_scaled = StandardScaler().fit_transform(X_continuous)

X_train_continuous, X_val_continuous, y_train_continuous, y_val_continuous = train_test_split(
    X_continuous_scaled, y, test_size=0.2, random_state=42)

knn_continuous = KNeighborsClassifier(n_neighbors=optimal_k)
knn_continuous.fit(X_train_continuous, y_train_continuous)
error_rate_continuous = 1 - knn_continuous.score(X_val_continuous, y_val_continuous)

X_all = A.drop('Undecided', axis=1)
X_all_scaled = StandardScaler().fit_transform(X_all)

X_train_all, X_val_all, y_train_all, y_val_all = train_test_split(
    X_all_scaled, y, test_size=0.2, random_state=42)

knn_all = KNeighborsClassifier(n_neighbors=optimal_k)
knn_all.fit(X_train_all, y_train_all)
error_rate_all = 1 - knn_all.score(X_val_all, y_val_all)

print(f"Error Rate (Continuous Variables Only): {error_rate_continuous:.4f}")
print(f"Error Rate (All Variables): {error_rate_all:.4f}")
# Out:
# Error Rate (Continuous Variables Only): 0.2080
# Error Rate (All Variables): 0.0715
